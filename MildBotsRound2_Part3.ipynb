# %% [markdown]
# <a href="https://colab.research.google.com/github/rjmynk/NLP_Project_MildBots/blob/main/MildBotsRound2_Part3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project Round 2

# %% [markdown]
# Importing the required modules

# %%
import pandas as pd

import matplotlib.pyplot as plt
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Reading books -
# 1> Pride and Prejudice by Jane Austen
# 2> A Tale of Two Cities by Charles Dickens

# %%
f= open('/content/drive/My Drive/nlp project/Pride and Prejudice.txt', 'r')
text1=f.read()

# %%
k= open('/content/drive/My Drive/nlp project/A tale of two cities.txt', 'r')
text2=k.read()

# %%
m= open('/content/drive/My Drive/nlp project/The Life of the Caterpillar by Jean-Henri Fabre.txt','r')
text3=m.read()

# %% [markdown]
#  Cleaning of Text

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
import re
import string
def text_cleaning(text):
  # to remove special chars
  text= text.lower()
  text= re.sub('\[.*?\]', '', text)
  text = re.sub("\\W"," ",text) 
  # to remove links
  text = re.sub('https?://\S+|www\.\S+', '', text)
  #to remove punctuations
  text = re.sub('<.*?>+', '', text)
  text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
  text = re.sub('\n', '', text)
  text = re.sub('\w*\d\w*', '', text)
  text= re.sub("chapter ","",text)
  return text

# %%
text1=text_cleaning(text1)
text2=text_cleaning(text2)
text3=text_cleaning(text3)

# %%
corpus=[text1,text2,text3]
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
trsfm=vectorizer.fit_transform(corpus)
pd.DataFrame(trsfm.toarray(),columns=vectorizer.get_feature_names(),index=['doc1','doc2','doc3'])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#          aback   abandon  abandoned  ...   étendue     œneus  τρίφυλλον
# doc1  0.000000  0.000000   0.000000  ...  0.000000  0.000000   0.000000
# doc2  0.000126  0.000096   0.000961  ...  0.000000  0.000000   0.000000
# doc3  0.000000  0.000600   0.000901  ...  0.000197  0.000197   0.000395
#
# [3 rows x 15785 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity(trsfm[0], trsfm)
# Out:
# array([[1.        , 0.91968738, 0.78726957]])

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity(trsfm[1], trsfm)
# Out:
# array([[0.91968738, 1.        , 0.89938099]])

# %%
from nltk.corpus import wordnet
nltk.download('wordnet')

from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

def lemmatizetext(sentence):
    token_words=word_tokenize(sentence) 
    lemma_sentence=[]
    for word in token_words:
        lemma_sentence.append(lemmatizer.lemmatize(word))
        lemma_sentence.append(" ")
    return "".join(lemma_sentence)

text1 = lemmatizetext(text1)
text2 = lemmatizetext(text2)
text3 = lemmatizetext(text3)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
corpus=[text1,text2,text3]
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
trsfm=vectorizer.fit_transform(corpus)
pd.DataFrame(trsfm.toarray(),columns=vectorizer.get_feature_names(),index=['doc1','doc2','doc3'])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#          aback   abandon  abandoned  ...   étendue     œneus  τρίφυλλον
# doc1  0.000000  0.000000   0.000000  ...  0.000000  0.000000   0.000000
# doc2  0.000126  0.000096   0.000961  ...  0.000000  0.000000   0.000000
# doc3  0.000000  0.000748   0.000897  ...  0.000197  0.000197   0.000393
#
# [3 rows x 13910 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity(trsfm[0], trsfm)
# Out:
# array([[1.        , 0.91781682, 0.78505921]])

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity(trsfm[1], trsfm)
# Out:
# array([[0.91781682, 1.        , 0.89863276]])
